# %% [markdown]
# # Setup

# %%
# !gcloud auth application-default login --no-launch-browser

# %%
project_id = "projects-264723"
# !gcloud config set project $project_id
# !git clone https://github.com/lejinvarghese/casper
# Out:
# Cloning into 'casper'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 19 (delta 6), reused 14 (delta 5), pack-reused 0
# Unpacking objects: 100% (19/19), 10.68 KiB | 607.00 KiB/s, done.

# %%
# !pip install -r casper/requirements.txt -qqq

# %% [markdown]
# # Import

# %%
from casper.main import train
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/lejinvarghese/clm/40f736d1cb8e4846ab5a1029b1a054c4
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# ...

# %% [markdown]
# # Run

# %%
train()
# Out:
# ...
# Generating train split:   0%|          | 0/346 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/Whispering-GPT___parquet/Whispering-GPT--lex-fridman-podcast-f9b59d9d94797791/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
# ...
# Filter:   0%|          | 0/346 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'channel', 'channel_id', 'title', 'categories', 'tags', 'description', 'text', 'segments'],
#     num_rows: 346
# })
# Dataset({
#     features: ['id', 'channel', 'channel_id', 'title', 'categories', 'tags', 'description', 'text', 'segments'],
#     num_rows: 275
# })
# ['Jed Buchwald: Isaac Newton and the Philosophy of Science | Lex Fridman Podcast #214', 'Sergey Nazarov: Chainlink, Smart Contracts, and Oracle Networks | Lex Fridman Podcast #181', 'Stephen Wolfram: Fundamental Theory of Physics, Life, and the Universe | Lex Fridman Podcast #124']
# ...
